# %% [markdown]
# #stiil 1
# ##stiil 2
# #####stiil 3

# %%
a = "tekst" #string
b = 5 #integer ehk arv
c = 0.1 #float ehk komakohaga number
d = True #boolean ehkk loogika väärtus
e = ["tiiger","koer"]

# %%
a=0.5*0.2+0.1**0.5
print(a)
b=7//2 + 7%2
print (b)
c=1 != 2 or 3<2
print (c)
string1="kass"
string2="koer"
d=string1+string2
print(d)
e=string1*2+string2
print(e)
set1={'puu','pruun','pere'}
set2={'table','water'}
j=set1^set2
print(j)
# Out:
# 0.416227766017
# 4
# True
# kasskoer
# kasskasskoer
# set(['water', 'table', 'pruun', 'pere', 'puu'])
